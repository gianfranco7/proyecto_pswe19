# %%
import os
import csv
import numpy as np
import pandas as pd
import skfuzzy as fuzz
import matplotlib as mpl
from matplotlib import cm
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler


#El csv debe estar en el mismo folder del archivo python
current_dir = os.getcwd()
filename = "crime_incidence.csv"

dataset_path = os.path.join(current_dir, filename)
df = pd.read_csv(dataset_path)

df.head()
# Out:
#    Province      Canton  Crimes at Noon  Crimes at Morning  \
# 0  ALAJUELA    ALAJUELA            1593               1275
# 1  ALAJUELA      ATENAS             116                 60
# 2  ALAJUELA      GRECIA             162                144
# 3  ALAJUELA     GUATUSO             118                 64
# 4  ALAJUELA  LOS CHILES             135                131
#
#    Crimes at Afternoon  Crimes at Night  Total Crimes  Province Percentage  \
# 0                 1600             1972          6440            42.254445
# 1                  100              104           380             2.493275
# 2                  184              240           730             4.789712
# 3                   44               45           271             1.778099
# 4                  159              187           612             4.015485
#
#    Country Percentage Crime Rate
# 0            6.648497  Very High
# 1            0.392303        Low
# 2            0.753634   Modarate
# ...

# %% [markdown]
# # Normalizacion de Datos en inceidencias.csv
# - Usando un MinMax Scaler de Sklearn

# %%
# Seleccion de columnas numericas
numeric_columns = df.columns[2:6]

print(numeric_columns)

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Normalizacion de Columnas
normalized_values = scaler.fit_transform(df[numeric_columns])

# Agregar columnas normalizadas al Dataframe
for i, col in enumerate(numeric_columns):
    df[f'{col}_norm'] = normalized_values[:, i]


df.reset_index(drop=True, inplace=True)

df.sample(10)
# Out:
# Index(['Crimes at Noon', 'Crimes at Morning', 'Crimes at Afternoon',
#        'Crimes at Night'],
#       dtype='object')
#       Province         Canton  Crimes at Noon  Crimes at Morning  \
# 54  PUNTARENAS        ESPARZA             184                119
# 4     ALAJUELA     LOS CHILES             135                131
# 81    SAN JOSE          TIBAS             294                174
# 74    SAN JOSE           MORA              96                 80
# 35     HEREDIA          BARVA             203                104
# 45       LIMON        GUACIMO             157                 77
# 57  PUNTARENAS  MONTES DE ORO              29                 24
# 64    SAN JOSE         ACOSTA              43                 37
# 10    ALAJUELA     SAN CARLOS             719                571
# 36     HEREDIA          BELEN             125                 88
#
#     Crimes at Afternoon  Crimes at Night  Total Crimes  Province Percentage  \
# ...

# %%
# !pip install transformers
# !pip install torch
#!pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html

import torch
from transformers import pipeline
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\pyke-1.1.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\pyke-1.1.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# ...

# %%
tqa = pipeline(task="table-question-answering", 
               model="google/tapas-base-finetuned-wtq")
     
table = df.astype(str)
# Out:
# Device set to use cpu

# %%
query = "How many Crimes at night are there in ESPARZA Canton?"
print(tqa(table=table, query=query)["answer"])
# Out:
# c:\Python312\Lib\site-packages\transformers\models\tapas\tokenization_tapas.py:2699: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text = normalize_for_match(row[col_index].text)
# c:\Python312\Lib\site-packages\transformers\models\tapas\tokenization_tapas.py:1493: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell = row[col_index]
# AVERAGE >

# %%
val = df.loc[df['Province'] == 'LIMON']
print(val)
# Out:
#    Province     Canton  Crimes at Noon  Crimes at Morning  \
# 45    LIMON    GUACIMO             157                 77
# 46    LIMON      LIMON             621                419
# 47    LIMON     MATINA             302                197
# 48    LIMON     POCOCI             752                399
# 49    LIMON  SIQUIRRES             300                286
# 50    LIMON  TALAMANCA             319                295
#
#     Crimes at Afternoon  Crimes at Night  Total Crimes  Province Percentage  \
# 45                   88              172           494             5.719579
# 46                  548              688          2276            26.351743
# 47                  234              331          1064            12.319092
# 48                  420              649          2220            25.703369
# 49                  311              337          1234            14.287368
# 50                  459              276          1349            15.618849
#
# ...
